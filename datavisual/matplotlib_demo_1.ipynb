# %%
import matplotlib.pyplot as plt
# from matplotlib import pyplot 

x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

plt.plot(x,y)
plt.show()

# %%
x1 = ['Mon', 'Tue', 'Wed', 'Thus', 'Fri', 'Sat', 'Sun']
y1 = [2, 5, 6, 2, 9, 10, 15]

plt.plot(x1, y1)
plt.title("This is my Title")

plt.xlabel("Day of the Week")
plt.ylabel("Sales Per Day")

plt.show()
