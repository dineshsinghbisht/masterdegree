# %% [markdown]
# ### Did you do Khan academy materials?
# Yes, thank you for the suggestion. I have signed up on khanacademy.org and used it to get a better understanding of the mathematical terms vectors, scalars, and matrices.
#
# ### Did you watch Youtube videos
# Yes, I watched YouTube videos mainly from the Khan Academy channel, along with a few other videos I came across while searching for related topics.
#
# ### Describe the kind of environment you have set up or where you are doing the exercises for this course.
# I am doing the exercises for this course on my work laptop, using a local development setup. I have Python and VS Code installed and I'll be working within a Python virtual environment to keep dependencies isolated for this course. I'll also be using Git and GitHub as well for version control, so I can track my progress and keep the exercises available for future reference.
#
# ### Why did you choose this approach?
# I chose this approach mainly because I'm comfortable and familiar with it. I did use the same setup (local Python, VS Code, virtual environments, and Git/GitHub for version control) for my two earlier courses, Advanced Data Analytics and Advanced Machine Learning, and it worked well for me both times. Sticking with a consistent environment across courses also means less time spent on setup and configuration, and more time focused on the actual course material.
