# %%
from getpass import getuser
import pandas as pd
import matplotlib.pyplot as plt

# user = getuser()
# csv_location = f'/home/{user}/dan/public/exrc_04/data/prob4_weather.csv'
csv_location = "prob4_weather.csv"
# csv_location =  "FILE_NAME" ### GIVE FILE_NAME TO RUN THE CODE LOCALLY

# Load input CSV data which contains contains some hourly temperature forecast data for Jyväskylä (2022-2023)
df = pd.read_csv(csv_location)

# Lets describe and check the data and properties of dataframe
print(df.info())  # prints concise summary about DataFrame's structure
print(df.columns) # prints information about columns
print(df.head())  # prints first five rows - default
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   air_temperature_2m  8784 non-null   float64
#  1   time                8784 non-null   float64
# dtypes: float64(2)
# memory usage: 137.4 KB
# None
# Index(['air_temperature_2m', 'time'], dtype='object')
#    air_temperature_2m          time
# 0          271.370819  1.647043e+09
# 1          270.397156  1.647047e+09
# 2          269.911011  1.647050e+09
# 3          269.699951  1.647054e+09
# 4          269.601532  1.647058e+09
