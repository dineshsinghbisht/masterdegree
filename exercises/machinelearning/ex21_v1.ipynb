# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import matplotlib.pyplot as plt

# Load monthly-car-sales.csv datatseet into pandas DataFrame
df = pd.read_csv("monthly-car-sales.csv")

# # Get basic information about data
# print(df.info())

df["Month"] = pd.to_datetime(df["Month"])
df["Time"] = df.index

seq_length = 12         # months
prediction_time = 12    # months

# Create a stationary time series
df["SalesLag"] = df["Sales"].shift(1)
df["SalesDiff"] = df.apply(lambda row:
    row["Sales"] - row["SalesLag"], axis=1)


for i in range(1, seq_length):
    df["SalesDiffLag" + str(i)] = df["SalesDiff"].shift(i)

for i in range(1, prediction_time + 1):
    df["SalesDiffFut" + str(i)] = df["SalesDiff"].shift(-i)

df_train = df.iloc[:-2*prediction_time]
df_train.dropna(inplace=True)
df_test = df.iloc[-2*prediction_time:]

# Define and Scale Variables
input_vars = ["SalesDiff"]
for i in range(1, seq_length):
    input_vars.append("SalesDiffLag" + str(i))

output_vars = []
for i in range(1, prediction_time + 1):
    output_vars.append("SalesDiffFut" + str(i))

scaler = StandardScaler()
scalero = StandardScaler()

X = np.array(df_train[input_vars])
X_scaled = scaler.fit_transform(X)
X_scaledLSTM = X_scaled.reshape(X.shape[0], X.shape[1], 1)
y = np.array(df_train[output_vars])
y_scaled = scalero.fit_transform(y)

X_test = np.array(df_test[input_vars])
X_testscaled = scaler.transform(X_test)
X_testscaledLSTM = X_testscaled.reshape(X_test.shape[0], X_test.shape[1], 1)

modelLR = LinearRegression()
XLR = np.array(df_train[["Time"]])
yLR = np.array(df_train[["Sales"]])
modelLR.fit(XLR, yLR)
slope = modelLR.coef_

modelLSTM = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, input_shape=(seq_length, 1),
                         return_sequences=False),
    tf.keras.layers.Dense(prediction_time)
])

modelLSTM.compile(
    tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

modelLSTM.fit(
    X_scaledLSTM,
    y_scaled, epochs=200, batch_size = seq_length
)

predictionDiff = scalero.inverse_transform(
    modelLSTM.predict(X_testscaledLSTM[prediction_time - 1].reshape(1, 12, 1))
)
prediction = np.zeros(13)
prediction[0] = df_test["Sales"].iloc[-1-prediction_time]

for i in range(1, 13):
    prediction[i] = prediction[i-1] + predictionDiff[0][i-1] + slope
prediction = np.array(prediction[1:])

df_pred = df_test[-12: ]
df_pred["SalesPred"] = prediction


plt.figure(figsize=(10, 6))
plt.plot(df["Month"].values, df["Sales"].values, color ="black", label="Actual Sales")
plt.plot(df_pred["Month"].values, df_pred["SalesPred"], color ="red", label="Prediction")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

print(f"Mean Absolute Error in the test data: {mean_absolute_error(df_pred["Sales"].values,  df_pred["SalesPred"]):.2f}")
# Out:
# Epoch 1/200
# /var/folders/0t/k860jmxx4d5__9h3p08nh77m0000gn/T/ipykernel_12533/696561907.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.dropna(inplace=True)
# /Users/dineshbisht/masterdegree/myproject_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0029 - mae: 0.7922
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9907 - mae: 0.7869
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9786 - mae: 0.7817
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9660 - mae: 0.7762
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9536 - mae: 0.7705
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9371 - mae: 0.7634
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9170 - mae: 0.7549
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8936 - mae: 0.7446
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8595 - mae: 0.7308
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8204 - mae: 0.7161
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7875 - mae: 0.7005
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7637 - mae: 0.6870
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7415 - mae: 0.6752
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7157 - mae: 0.6620
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6924 - mae: 0.6498
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6719 - mae: 0.6398
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6437 - mae: 0.6275
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6174 - mae: 0.6157
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5921 - mae: 0.6045
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5656 - mae: 0.5917
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5412 - mae: 0.5797
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5201 - mae: 0.5688
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4995 - mae: 0.5570
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4832 - mae: 0.5489
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4630 - mae: 0.5385
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4479 - mae: 0.5304
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4313 - mae: 0.5192
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4145 - mae: 0.5090
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4005 - mae: 0.5021
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3880 - mae: 0.4933
# Epoch 31/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3779 - mae: 0.4868
# Epoch 32/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3693 - mae: 0.4829
# Epoch 33/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3654 - mae: 0.4815
# Epoch 34/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3593 - mae: 0.4768
# Epoch 35/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3523 - mae: 0.4720
# Epoch 36/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3457 - mae: 0.4685
# Epoch 37/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3425 - mae: 0.4656
# Epoch 38/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3376 - mae: 0.4630
# Epoch 39/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3348 - mae: 0.4612
# Epoch 40/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3315 - mae: 0.4579
# Epoch 41/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3273 - mae: 0.4556
# Epoch 42/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3237 - mae: 0.4532
# Epoch 43/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3223 - mae: 0.4516
# Epoch 44/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3194 - mae: 0.4507
# Epoch 45/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3169 - mae: 0.4469
# Epoch 46/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3138 - mae: 0.4466
# Epoch 47/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3106 - mae: 0.4440
# Epoch 48/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3084 - mae: 0.4417
# Epoch 49/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3050 - mae: 0.4393
# Epoch 50/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3040 - mae: 0.4387
# Epoch 51/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3008 - mae: 0.4371
# Epoch 52/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2981 - mae: 0.4342
# Epoch 53/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2961 - mae: 0.4327
# Epoch 54/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2967 - mae: 0.4341
# Epoch 55/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2927 - mae: 0.4297
# Epoch 56/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2904 - mae: 0.4290
# Epoch 57/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2882 - mae: 0.4279
# Epoch 58/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2854 - mae: 0.4236
# Epoch 59/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2829 - mae: 0.4229
# Epoch 60/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2807 - mae: 0.4228
# Epoch 61/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2778 - mae: 0.4201
# Epoch 62/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2775 - mae: 0.4199
# Epoch 63/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2739 - mae: 0.4175
# Epoch 64/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2736 - mae: 0.4162
# Epoch 65/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2710 - mae: 0.4153
# Epoch 66/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2681 - mae: 0.4121
# Epoch 67/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2662 - mae: 0.4117
# Epoch 68/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2647 - mae: 0.4109
# Epoch 69/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2619 - mae: 0.4080
# Epoch 70/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2608 - mae: 0.4068
# Epoch 71/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2581 - mae: 0.4056
# Epoch 72/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2550 - mae: 0.4029
# Epoch 73/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2549 - mae: 0.4016
# Epoch 74/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2515 - mae: 0.3999
# Epoch 75/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2509 - mae: 0.3988
# Epoch 76/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2480 - mae: 0.3970
# Epoch 77/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2467 - mae: 0.3966
# Epoch 78/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2438 - mae: 0.3934
# Epoch 79/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2429 - mae: 0.3928
# Epoch 80/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2405 - mae: 0.3911
# Epoch 81/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2383 - mae: 0.3894
# Epoch 82/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2376 - mae: 0.3886
# Epoch 83/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2337 - mae: 0.3852
# Epoch 84/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2333 - mae: 0.3855
# Epoch 85/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2319 - mae: 0.3834
# Epoch 86/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2286 - mae: 0.3810
# Epoch 87/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2269 - mae: 0.3805
# Epoch 88/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2265 - mae: 0.3799
# Epoch 89/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2239 - mae: 0.3775
# Epoch 90/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2237 - mae: 0.3771
# Epoch 91/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2208 - mae: 0.3745
# Epoch 92/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2189 - mae: 0.3740
# Epoch 93/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2167 - mae: 0.3717
# Epoch 94/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2153 - mae: 0.3702
# Epoch 95/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2135 - mae: 0.3687
# Epoch 96/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2117 - mae: 0.3672
# Epoch 97/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2100 - mae: 0.3659
# Epoch 98/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2095 - mae: 0.3662
# Epoch 99/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2087 - mae: 0.3653
# Epoch 100/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2073 - mae: 0.3626
# Epoch 101/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2073 - mae: 0.3646
# Epoch 102/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2050 - mae: 0.3629
# Epoch 103/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2000 - mae: 0.3583
# Epoch 104/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2012 - mae: 0.3586
# Epoch 105/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2002 - mae: 0.3581
# Epoch 106/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1980 - mae: 0.3573
# Epoch 107/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1973 - mae: 0.3549
# Epoch 108/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1950 - mae: 0.3527
# Epoch 109/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1944 - mae: 0.3528
# Epoch 110/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1927 - mae: 0.3507
# Epoch 111/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1909 - mae: 0.3503
# Epoch 112/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1910 - mae: 0.3502
# Epoch 113/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1904 - mae: 0.3499
# Epoch 114/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1879 - mae: 0.3476
# Epoch 115/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1854 - mae: 0.3457
# Epoch 116/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1851 - mae: 0.3447
# Epoch 117/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1842 - mae: 0.3441
# Epoch 118/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1815 - mae: 0.3419
# Epoch 119/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1817 - mae: 0.3411
# Epoch 120/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1801 - mae: 0.3400
# Epoch 121/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1793 - mae: 0.3398
# Epoch 122/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1770 - mae: 0.3371
# Epoch 123/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1774 - mae: 0.3382
# Epoch 124/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1756 - mae: 0.3359
# Epoch 125/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1743 - mae: 0.3347
# Epoch 126/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1742 - mae: 0.3357
# Epoch 127/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1719 - mae: 0.3330
# Epoch 128/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1707 - mae: 0.3308
# Epoch 129/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1695 - mae: 0.3299
# Epoch 130/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1697 - mae: 0.3306
# Epoch 131/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1679 - mae: 0.3291
# Epoch 132/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1674 - mae: 0.3289
# Epoch 133/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1655 - mae: 0.3258
# Epoch 134/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1641 - mae: 0.3254
# Epoch 135/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1635 - mae: 0.3243
# Epoch 136/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1623 - mae: 0.3238
# Epoch 137/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1623 - mae: 0.3235
# Epoch 138/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1627 - mae: 0.3238
# Epoch 139/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1594 - mae: 0.3213
# Epoch 140/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1585 - mae: 0.3200
# Epoch 141/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1561 - mae: 0.3169
# Epoch 142/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1558 - mae: 0.3169
# Epoch 143/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1547 - mae: 0.3159
# Epoch 144/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1550 - mae: 0.3156
# Epoch 145/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1529 - mae: 0.3133
# Epoch 146/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1526 - mae: 0.3133
# Epoch 147/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1508 - mae: 0.3122
# Epoch 148/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1502 - mae: 0.3108
# Epoch 149/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1490 - mae: 0.3098
# Epoch 150/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1487 - mae: 0.3095
# Epoch 151/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1495 - mae: 0.3108
# Epoch 152/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1488 - mae: 0.3077
# Epoch 153/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1492 - mae: 0.3081
# Epoch 154/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1482 - mae: 0.3086
# Epoch 155/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1451 - mae: 0.3044
# Epoch 156/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1443 - mae: 0.3039
# Epoch 157/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1420 - mae: 0.3007
# Epoch 158/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1408 - mae: 0.3011
# Epoch 159/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1398 - mae: 0.2990
# Epoch 160/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1389 - mae: 0.2980
# Epoch 161/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1380 - mae: 0.2975
# Epoch 162/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1372 - mae: 0.2965
# Epoch 163/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1373 - mae: 0.2964
# Epoch 164/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1364 - mae: 0.2955
# Epoch 165/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1345 - mae: 0.2931
# Epoch 166/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1339 - mae: 0.2930
# Epoch 167/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1336 - mae: 0.2921
# Epoch 168/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1319 - mae: 0.2910
# Epoch 169/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1316 - mae: 0.2905
# Epoch 170/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1304 - mae: 0.2878
# Epoch 171/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1294 - mae: 0.2878
# Epoch 172/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1282 - mae: 0.2866
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1277 - mae: 0.2846
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1262 - mae: 0.2837
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1256 - mae: 0.2830
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1251 - mae: 0.2818
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1240 - mae: 0.2813
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1251 - mae: 0.2831
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1241 - mae: 0.2817
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1263 - mae: 0.2839
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1244 - mae: 0.2809
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1215 - mae: 0.2776
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1203 - mae: 0.2763
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1196 - mae: 0.2748
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1197 - mae: 0.2746
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1200 - mae: 0.2762
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1176 - mae: 0.2726
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1161 - mae: 0.2711
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1163 - mae: 0.2712
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1151 - mae: 0.2704
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1140 - mae: 0.2686
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1127 - mae: 0.2661
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1119 - mae: 0.2649
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1115 - mae: 0.2649
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1109 - mae: 0.2637
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1100 - mae: 0.2623
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1089 - mae: 0.2622
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1090 - mae: 0.2610
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1080 - mae: 0.2597
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1080 - mae: 0.2604
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# /var/folders/0t/k860jmxx4d5__9h3p08nh77m0000gn/T/ipykernel_12533/696561907.py:89: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   prediction[i] = prediction[i-1] + predictionDiff[0][i-1] + slope
# /var/folders/0t/k860jmxx4d5__9h3p08nh77m0000gn/T/ipykernel_12533/696561907.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pred["SalesPred"] = prediction
# Mean absolute error in the test data: 1208.81
