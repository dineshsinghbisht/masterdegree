# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import matplotlib.pyplot as plt

# Load monthly-car-sales.csv dataset into a pandas DataFrame
df = pd.read_csv("monthly-car-sales.csv")

# Convert Month column to datetime and create a numeric time index
df["Month"] = pd.to_datetime(df["Month"])
df["Time"] = df.index

seq_length = 12         # months
prediction_time = 12    # months

# Create a stationary time series by computing month-over-month differences
df["SalesLag"] = df["Sales"].shift(1)
df["SalesDiff"] = df.apply(lambda row:
    row["Sales"] - row["SalesLag"], axis=1)

# Create lag features (past 11 months of differences as inputs)
for i in range(1, seq_length):
    df["SalesDiffLag" + str(i)] = df["SalesDiff"].shift(i)

# Create future features (next 12 months of differences as targets)
for i in range(1, prediction_time + 1):
    df["SalesDiffFut" + str(i)] = df["SalesDiff"].shift(-i)

# Split into training (1961-1966) and test (1967-1968) datasets
df_train = df.iloc[:-2*prediction_time]
df_train.dropna(inplace=True)
df_test = df.iloc[-2*prediction_time:]

# Define input variables (current diff + 11 lags) and output variables (next 12 diffs)
input_vars = ["SalesDiff"]
for i in range(1, seq_length):
    input_vars.append("SalesDiffLag" + str(i))

output_vars = []
for i in range(1, prediction_time + 1):
    output_vars.append("SalesDiffFut" + str(i))

# Scale input and output variables using separate StandardScalers
scaler = StandardScaler()
scalero = StandardScaler()

X = np.array(df_train[input_vars])
X_scaled = scaler.fit_transform(X)
X_scaledLSTM = X_scaled.reshape(X.shape[0], X.shape[1], 1)
y = np.array(df_train[output_vars])
y_scaled = scalero.fit_transform(y)

X_test = np.array(df_test[input_vars])
X_testscaled = scaler.transform(X_test)
X_testscaledLSTM = X_testscaled.reshape(X_test.shape[0], X_test.shape[1], 1)

# Fit a Linear Regression model to capture the long-term sales trend (slope)
modelLR = LinearRegression()
XLR = np.array(df_train[["Time"]])
yLR = np.array(df_train[["Sales"]])
modelLR.fit(XLR, yLR)
slope = modelLR.coef_

# Build LSTM model with 50 units and a Dense output layer for 12-month prediction
modelLSTM = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, input_shape=(seq_length, 1),
                         return_sequences=False),
    tf.keras.layers.Dense(prediction_time)
])

# Compile the LSTM model with Adam optimiser and MSE loss
modelLSTM.compile(
    tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# Train the LSTM model on the scaled training data
modelLSTM.fit(
    X_scaledLSTM,
    y_scaled, epochs=200, batch_size=seq_length
)

# Predict the 12 monthly differences for 1968 using December 1967 as input
predictionDiff = scalero.inverse_transform(
    modelLSTM.predict(X_testscaledLSTM[prediction_time - 1].reshape(1, 12, 1))
)

# Reconstruct actual Sales from differences: Sales = PrevSales + SalesDiff + trend
prediction = np.zeros(13)
prediction[0] = df_test["Sales"].iloc[-1-prediction_time]   # anchor to Dec 1967
for i in range(1, 13):
    prediction[i] = prediction[i-1] + predictionDiff[0][i-1] + slope
prediction = np.array(prediction[1:])

# Store predictions in the test DataFrame
df_pred = df_test[-12:]
df_pred["SalesPred"] = prediction

# Plot actual vs predicted sales for the full dataset
plt.figure(figsize=(10, 6))
plt.plot(df["Month"].values, df["Sales"].values, color="black", label="Actual Sales")
plt.plot(df_pred["Month"].values, df_pred["SalesPred"], color="red", label="Prediction")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# Evaluate and display model accuracy with Mean Absolute Error for the test dataset
print(f"Mean Absolute Error in the test data: {mean_absolute_error(df_pred['Sales'].values, df_pred['SalesPred']):.2f}")
# Out:
# Epoch 1/200
# /var/folders/0t/k860jmxx4d5__9h3p08nh77m0000gn/T/ipykernel_12942/819332004.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.dropna(inplace=True)
# /Users/dineshbisht/masterdegree/myproject_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9928 - mae: 0.7873
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9820 - mae: 0.7824
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9715 - mae: 0.7778
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9610 - mae: 0.7732
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9489 - mae: 0.7677
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9354 - mae: 0.7618
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9172 - mae: 0.7546
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8965 - mae: 0.7469
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8667 - mae: 0.7361
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8346 - mae: 0.7253
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8017 - mae: 0.7127
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7759 - mae: 0.6983
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7516 - mae: 0.6841
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7251 - mae: 0.6699
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7028 - mae: 0.6570
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6771 - mae: 0.6453
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6525 - mae: 0.6337
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6224 - mae: 0.6190
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5962 - mae: 0.6067
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5710 - mae: 0.5937
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5541 - mae: 0.5870
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5322 - mae: 0.5759
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5109 - mae: 0.5660
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4908 - mae: 0.5550
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4681 - mae: 0.5429
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4511 - mae: 0.5328
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4402 - mae: 0.5254
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4179 - mae: 0.5108
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4000 - mae: 0.4997
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3856 - mae: 0.4904
# Epoch 31/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3712 - mae: 0.4813
# Epoch 32/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3624 - mae: 0.4747
# Epoch 33/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3521 - mae: 0.4696
# Epoch 34/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3444 - mae: 0.4651
# Epoch 35/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3394 - mae: 0.4608
# Epoch 36/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3343 - mae: 0.4574
# Epoch 37/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3290 - mae: 0.4545
# Epoch 38/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3246 - mae: 0.4506
# Epoch 39/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3213 - mae: 0.4481
# Epoch 40/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3180 - mae: 0.4466
# Epoch 41/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3158 - mae: 0.4436
# Epoch 42/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3126 - mae: 0.4415
# Epoch 43/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3091 - mae: 0.4386
# Epoch 44/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3064 - mae: 0.4369
# Epoch 45/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3048 - mae: 0.4354
# Epoch 46/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3032 - mae: 0.4356
# Epoch 47/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3019 - mae: 0.4337
# Epoch 48/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2975 - mae: 0.4300
# Epoch 49/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2962 - mae: 0.4305
# Epoch 50/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2924 - mae: 0.4269
# Epoch 51/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2914 - mae: 0.4253
# Epoch 52/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2895 - mae: 0.4252
# Epoch 53/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2870 - mae: 0.4226
# Epoch 54/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2830 - mae: 0.4204
# Epoch 55/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2821 - mae: 0.4188
# Epoch 56/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2800 - mae: 0.4173
# Epoch 57/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2775 - mae: 0.4159
# Epoch 58/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2773 - mae: 0.4150
# Epoch 59/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2727 - mae: 0.4114
# Epoch 60/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2722 - mae: 0.4117
# Epoch 61/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2708 - mae: 0.4099
# Epoch 62/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2685 - mae: 0.4083
# Epoch 63/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2681 - mae: 0.4071
# Epoch 64/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2637 - mae: 0.4043
# Epoch 65/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2636 - mae: 0.4061
# Epoch 66/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2632 - mae: 0.4042
# Epoch 67/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2606 - mae: 0.4026
# Epoch 68/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2608 - mae: 0.4023
# Epoch 69/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2560 - mae: 0.3993
# Epoch 70/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2538 - mae: 0.3966
# Epoch 71/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2531 - mae: 0.3959
# Epoch 72/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2506 - mae: 0.3951
# Epoch 73/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2489 - mae: 0.3920
# Epoch 74/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2485 - mae: 0.3933
# Epoch 75/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2456 - mae: 0.3912
# Epoch 76/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2442 - mae: 0.3888
# Epoch 77/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2417 - mae: 0.3882
# Epoch 78/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2405 - mae: 0.3875
# Epoch 79/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2389 - mae: 0.3861
# Epoch 80/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2414 - mae: 0.3866
# Epoch 81/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2362 - mae: 0.3843
# Epoch 82/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2349 - mae: 0.3828
# Epoch 83/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2326 - mae: 0.3804
# Epoch 84/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2317 - mae: 0.3803
# Epoch 85/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2302 - mae: 0.3787
# Epoch 86/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2276 - mae: 0.3762
# Epoch 87/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2273 - mae: 0.3779
# Epoch 88/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2255 - mae: 0.3756
# Epoch 89/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2240 - mae: 0.3739
# Epoch 90/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2244 - mae: 0.3761
# Epoch 91/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2229 - mae: 0.3735
# Epoch 92/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2204 - mae: 0.3711
# Epoch 93/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2186 - mae: 0.3711
# Epoch 94/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2178 - mae: 0.3703
# Epoch 95/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2168 - mae: 0.3690
# Epoch 96/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2148 - mae: 0.3681
# Epoch 97/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2142 - mae: 0.3676
# Epoch 98/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2127 - mae: 0.3664
# Epoch 99/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2122 - mae: 0.3663
# Epoch 100/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2114 - mae: 0.3652
# Epoch 101/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2092 - mae: 0.3640
# Epoch 102/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2077 - mae: 0.3629
# Epoch 103/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2080 - mae: 0.3622
# Epoch 104/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2066 - mae: 0.3630
# Epoch 105/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2057 - mae: 0.3619
# Epoch 106/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2048 - mae: 0.3604
# Epoch 107/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2037 - mae: 0.3588
# Epoch 108/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2024 - mae: 0.3577
# Epoch 109/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2037 - mae: 0.3609
# Epoch 110/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2021 - mae: 0.3576
# Epoch 111/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2003 - mae: 0.3575
# Epoch 112/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1994 - mae: 0.3561
# Epoch 113/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1976 - mae: 0.3541
# Epoch 114/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1970 - mae: 0.3540
# Epoch 115/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1955 - mae: 0.3529
# Epoch 116/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1946 - mae: 0.3516
# Epoch 117/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1940 - mae: 0.3524
# Epoch 118/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1921 - mae: 0.3490
# Epoch 119/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1917 - mae: 0.3490
# Epoch 120/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1925 - mae: 0.3508
# Epoch 121/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1925 - mae: 0.3502
# Epoch 122/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1912 - mae: 0.3504
# Epoch 123/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1893 - mae: 0.3481
# Epoch 124/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1877 - mae: 0.3454
# Epoch 125/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1872 - mae: 0.3459
# Epoch 126/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1868 - mae: 0.3452
# Epoch 127/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1857 - mae: 0.3446
# Epoch 128/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1855 - mae: 0.3435
# Epoch 129/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1843 - mae: 0.3442
# Epoch 130/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1835 - mae: 0.3433
# Epoch 131/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1826 - mae: 0.3411
# Epoch 132/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1819 - mae: 0.3414
# Epoch 133/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1807 - mae: 0.3405
# Epoch 134/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1804 - mae: 0.3393
# Epoch 135/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1791 - mae: 0.3389
# Epoch 136/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1797 - mae: 0.3380
# Epoch 137/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1775 - mae: 0.3373
# Epoch 138/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1779 - mae: 0.3374
# Epoch 139/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1775 - mae: 0.3362
# Epoch 140/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1767 - mae: 0.3374
# Epoch 141/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1762 - mae: 0.3360
# Epoch 142/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1759 - mae: 0.3348
# Epoch 143/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1730 - mae: 0.3328
# Epoch 144/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1741 - mae: 0.3334
# Epoch 145/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1740 - mae: 0.3334
# Epoch 146/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1735 - mae: 0.3334
# Epoch 147/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1725 - mae: 0.3320
# Epoch 148/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1714 - mae: 0.3322
# Epoch 149/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1711 - mae: 0.3320
# Epoch 150/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1698 - mae: 0.3303
# Epoch 151/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1693 - mae: 0.3288
# Epoch 152/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1684 - mae: 0.3286
# Epoch 153/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1679 - mae: 0.3278
# Epoch 154/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1666 - mae: 0.3262
# Epoch 155/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1667 - mae: 0.3262
# Epoch 156/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1664 - mae: 0.3262
# Epoch 157/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1648 - mae: 0.3240
# Epoch 158/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1645 - mae: 0.3243
# Epoch 159/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1633 - mae: 0.3227
# Epoch 160/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1627 - mae: 0.3228
# Epoch 161/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1621 - mae: 0.3218
# Epoch 162/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1614 - mae: 0.3219
# Epoch 163/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1613 - mae: 0.3203
# Epoch 164/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1608 - mae: 0.3205
# Epoch 165/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1594 - mae: 0.3185
# Epoch 166/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1594 - mae: 0.3196
# Epoch 167/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1591 - mae: 0.3182
# Epoch 168/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1578 - mae: 0.3182
# Epoch 169/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1581 - mae: 0.3167
# Epoch 170/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1574 - mae: 0.3171
# Epoch 171/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1561 - mae: 0.3155
# Epoch 172/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1561 - mae: 0.3164
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1557 - mae: 0.3151
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1568 - mae: 0.3173
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1567 - mae: 0.3164
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1555 - mae: 0.3159
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1523 - mae: 0.3106
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1517 - mae: 0.3107
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1515 - mae: 0.3110
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1503 - mae: 0.3111
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1501 - mae: 0.3091
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1482 - mae: 0.3074
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1483 - mae: 0.3070
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1473 - mae: 0.3064
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1464 - mae: 0.3054
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1468 - mae: 0.3055
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1447 - mae: 0.3037
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1444 - mae: 0.3030
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1445 - mae: 0.3043
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1431 - mae: 0.3017
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1440 - mae: 0.3031
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1422 - mae: 0.3008
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1414 - mae: 0.3001
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1412 - mae: 0.3011
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1402 - mae: 0.2995
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1394 - mae: 0.2974
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1421 - mae: 0.3017
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1391 - mae: 0.2977
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1386 - mae: 0.2969
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1369 - mae: 0.2951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# /var/folders/0t/k860jmxx4d5__9h3p08nh77m0000gn/T/ipykernel_12942/819332004.py:96: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   prediction[i] = prediction[i-1] + predictionDiff[0][i-1] + slope
# /var/folders/0t/k860jmxx4d5__9h3p08nh77m0000gn/T/ipykernel_12942/819332004.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pred["SalesPred"] = prediction
# Mean Absolute Error in the test data: 1307.85
