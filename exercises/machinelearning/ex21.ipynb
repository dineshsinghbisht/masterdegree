# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import matplotlib.pyplot as plt

# Load monthly-car-sales.csv dataset into a pandas DataFrame
df = pd.read_csv("monthly-car-sales.csv")

# Convert Month column to datetime and create a numeric time index
df["Month"] = pd.to_datetime(df["Month"])
df["Time"] = df.index

seq_length = 12         # months
prediction_time = 12    # months

# Create a stationary time series by computing month-over-month differences
df["SalesLag"] = df["Sales"].shift(1)
df["SalesDiff"] = df.apply(lambda row:
    row["Sales"] - row["SalesLag"], axis=1)

# Create lag features (past 11 months of differences as inputs)
for i in range(1, seq_length):
    df["SalesDiffLag" + str(i)] = df["SalesDiff"].shift(i)

# Create future features (next 12 months of differences as targets)
for i in range(1, prediction_time + 1):
    df["SalesDiffFut" + str(i)] = df["SalesDiff"].shift(-i)

# Split into training (1961-1966) and test (1967-1968) datasets
df_train = df.iloc[:-2*prediction_time]
df_train.dropna(inplace=True)
df_test = df.iloc[-2*prediction_time:]

# Define input variables (current diff + 11 lags) and output variables (next 12 diffs)
input_vars = ["SalesDiff"]
for i in range(1, seq_length):
    input_vars.append("SalesDiffLag" + str(i))

output_vars = []
for i in range(1, prediction_time + 1):
    output_vars.append("SalesDiffFut" + str(i))

# Scale input and output variables using separate StandardScalers
scaler = StandardScaler()
scalero = StandardScaler()

X = np.array(df_train[input_vars])
X_scaled = scaler.fit_transform(X)
X_scaledLSTM = X_scaled.reshape(X.shape[0], X.shape[1], 1)
y = np.array(df_train[output_vars])
y_scaled = scalero.fit_transform(y)

X_test = np.array(df_test[input_vars])
X_testscaled = scaler.transform(X_test)
X_testscaledLSTM = X_testscaled.reshape(X_test.shape[0], X_test.shape[1], 1)

# Fit a Linear Regression model to capture the long-term sales trend (slope)
modelLR = LinearRegression()
XLR = np.array(df_train[["Time"]])
yLR = np.array(df_train[["Sales"]])
modelLR.fit(XLR, yLR)
slope = modelLR.coef_

# Build LSTM model with 50 units and a Dense output layer for 12-month prediction
modelLSTM = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, input_shape=(seq_length, 1),
                         return_sequences=False),
    tf.keras.layers.Dense(prediction_time)
])

# Compile the LSTM model with Adam optimiser and MSE loss
modelLSTM.compile(
    tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# Train the LSTM model on the scaled training data
modelLSTM.fit(
    X_scaledLSTM,
    y_scaled, epochs=200, batch_size=seq_length
)

# Predict the 12 monthly differences for 1968 using December 1967 as input
predictionDiff = scalero.inverse_transform(
    modelLSTM.predict(X_testscaledLSTM[prediction_time - 1].reshape(1, 12, 1))
)

# Reconstruct actual Sales from differences: Sales = PrevSales + SalesDiff + trend
prediction = np.zeros(13)
prediction[0] = df_test["Sales"].iloc[-1-prediction_time]   # anchor to Dec 1967
for i in range(1, 13):
    prediction[i] = prediction[i-1] + predictionDiff[0][i-1] + slope
prediction = np.array(prediction[1:])

# Store predictions in the test DataFrame
df_pred = df_test[-12:]
df_pred["SalesPred"] = prediction

# Plot actual vs predicted sales for the full dataset
plt.figure(figsize=(10, 6))
plt.plot(df["Month"].values, df["Sales"].values, color="black", label="Actual Sales")
plt.plot(df_pred["Month"].values, df_pred["SalesPred"], color="red", label="Prediction")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# Evaluate and display model accuracy with Mean Absolute Error for the test dataset
print(f"Mean Absolute Error in the test data: {mean_absolute_error(df_pred['Sales'].values, df_pred['SalesPred']):.2f}")
# Out:
# Epoch 1/200
# /var/folders/0t/k860jmxx4d5__9h3p08nh77m0000gn/T/ipykernel_12942/819332004.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.dropna(inplace=True)
# /Users/dineshbisht/masterdegree/myproject_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0040 - mae: 0.7928
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9922 - mae: 0.7875
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9808 - mae: 0.7825
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9683 - mae: 0.7768
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9540 - mae: 0.7702
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9377 - mae: 0.7627
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9153 - mae: 0.7529
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8854 - mae: 0.7397
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8492 - mae: 0.7244
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8107 - mae: 0.7105
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7940 - mae: 0.7035
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7754 - mae: 0.6945
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7565 - mae: 0.6842
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7385 - mae: 0.6761
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7207 - mae: 0.6680
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7002 - mae: 0.6583
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6792 - mae: 0.6476
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6563 - mae: 0.6387
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6330 - mae: 0.6288
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6080 - mae: 0.6192
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5813 - mae: 0.6074
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5551 - mae: 0.5962
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5358 - mae: 0.5882
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5094 - mae: 0.5751
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4864 - mae: 0.5624
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4687 - mae: 0.5524
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4495 - mae: 0.5395
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4272 - mae: 0.5264
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4091 - mae: 0.5136
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3947 - mae: 0.5030
# Epoch 31/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3808 - mae: 0.4940
# Epoch 32/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3681 - mae: 0.4858
# Epoch 33/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3577 - mae: 0.4773
# Epoch 34/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3509 - mae: 0.4715
# Epoch 35/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3455 - mae: 0.4695
# Epoch 36/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3375 - mae: 0.4633
# Epoch 37/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3352 - mae: 0.4608
# Epoch 38/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3315 - mae: 0.4588
# Epoch 39/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3272 - mae: 0.4559
# Epoch 40/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3240 - mae: 0.4535
# Epoch 41/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3218 - mae: 0.4519
# Epoch 42/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3183 - mae: 0.4494
# Epoch 43/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3153 - mae: 0.4469
# Epoch 44/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3131 - mae: 0.4452
# Epoch 45/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3112 - mae: 0.4435
# Epoch 46/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3088 - mae: 0.4422
# Epoch 47/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3061 - mae: 0.4400
# Epoch 48/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3043 - mae: 0.4386
# Epoch 49/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3025 - mae: 0.4368
# Epoch 50/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3005 - mae: 0.4355
# Epoch 51/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2995 - mae: 0.4353
# Epoch 52/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2974 - mae: 0.4336
# Epoch 53/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2951 - mae: 0.4313
# Epoch 54/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2937 - mae: 0.4309
# Epoch 55/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2914 - mae: 0.4285
# Epoch 56/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2895 - mae: 0.4273
# Epoch 57/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2869 - mae: 0.4260
# Epoch 58/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2865 - mae: 0.4260
# Epoch 59/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2833 - mae: 0.4230
# Epoch 60/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2827 - mae: 0.4223
# Epoch 61/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2809 - mae: 0.4225
# Epoch 62/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2787 - mae: 0.4191
# Epoch 63/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2746 - mae: 0.4160
# Epoch 64/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2738 - mae: 0.4166
# Epoch 65/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2723 - mae: 0.4143
# Epoch 66/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2695 - mae: 0.4126
# Epoch 67/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2688 - mae: 0.4123
# Epoch 68/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2652 - mae: 0.4087
# Epoch 69/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2641 - mae: 0.4097
# Epoch 70/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2621 - mae: 0.4060
# Epoch 71/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2608 - mae: 0.4059
# Epoch 72/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2588 - mae: 0.4044
# Epoch 73/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2550 - mae: 0.4011
# Epoch 74/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2532 - mae: 0.4003
# Epoch 75/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2522 - mae: 0.3986
# Epoch 76/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2503 - mae: 0.3973
# Epoch 77/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2468 - mae: 0.3943
# Epoch 78/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2458 - mae: 0.3940
# Epoch 79/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2428 - mae: 0.3915
# Epoch 80/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2403 - mae: 0.3893
# Epoch 81/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2387 - mae: 0.3881
# Epoch 82/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2359 - mae: 0.3858
# Epoch 83/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2361 - mae: 0.3858
# Epoch 84/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2337 - mae: 0.3846
# Epoch 85/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2329 - mae: 0.3837
# Epoch 86/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2296 - mae: 0.3810
# Epoch 87/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2279 - mae: 0.3802
# Epoch 88/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2274 - mae: 0.3786
# Epoch 89/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2255 - mae: 0.3779
# Epoch 90/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2226 - mae: 0.3767
# Epoch 91/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2240 - mae: 0.3765
# Epoch 92/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2212 - mae: 0.3752
# Epoch 93/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2203 - mae: 0.3745
# Epoch 94/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2164 - mae: 0.3705
# Epoch 95/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2164 - mae: 0.3705
# Epoch 96/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2144 - mae: 0.3690
# Epoch 97/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2114 - mae: 0.3676
# Epoch 98/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2103 - mae: 0.3669
# Epoch 99/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2105 - mae: 0.3667
# Epoch 100/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2081 - mae: 0.3644
# Epoch 101/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2069 - mae: 0.3638
# Epoch 102/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2050 - mae: 0.3617
# Epoch 103/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2053 - mae: 0.3616
# Epoch 104/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2042 - mae: 0.3610
# Epoch 105/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2012 - mae: 0.3582
# Epoch 106/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2021 - mae: 0.3599
# Epoch 107/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2000 - mae: 0.3583
# Epoch 108/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1978 - mae: 0.3567
# Epoch 109/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1952 - mae: 0.3527
# Epoch 110/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1952 - mae: 0.3540
# Epoch 111/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1932 - mae: 0.3522
# Epoch 112/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1920 - mae: 0.3517
# Epoch 113/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1912 - mae: 0.3503
# Epoch 114/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1895 - mae: 0.3498
# Epoch 115/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1889 - mae: 0.3483
# Epoch 116/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1876 - mae: 0.3473
# Epoch 117/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1857 - mae: 0.3460
# Epoch 118/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1875 - mae: 0.3479
# Epoch 119/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1846 - mae: 0.3455
# Epoch 120/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1836 - mae: 0.3437
# Epoch 121/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1830 - mae: 0.3425
# Epoch 122/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1813 - mae: 0.3426
# Epoch 123/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1801 - mae: 0.3408
# Epoch 124/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1791 - mae: 0.3406
# Epoch 125/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1781 - mae: 0.3393
# Epoch 126/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1765 - mae: 0.3378
# Epoch 127/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1763 - mae: 0.3382
# Epoch 128/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1751 - mae: 0.3372
# Epoch 129/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1744 - mae: 0.3360
# Epoch 130/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1748 - mae: 0.3358
# Epoch 131/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1742 - mae: 0.3362
# Epoch 132/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1739 - mae: 0.3356
# Epoch 133/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1739 - mae: 0.3376
# Epoch 134/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1725 - mae: 0.3332
# Epoch 135/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1696 - mae: 0.3324
# Epoch 136/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1697 - mae: 0.3305
# Epoch 137/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1677 - mae: 0.3302
# Epoch 138/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1663 - mae: 0.3287
# Epoch 139/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1644 - mae: 0.3269
# Epoch 140/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1643 - mae: 0.3267
# Epoch 141/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1631 - mae: 0.3247
# Epoch 142/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1626 - mae: 0.3260
# Epoch 143/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1607 - mae: 0.3238
# Epoch 144/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1602 - mae: 0.3227
# Epoch 145/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1595 - mae: 0.3224
# Epoch 146/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1590 - mae: 0.3223
# Epoch 147/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1581 - mae: 0.3202
# Epoch 148/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1574 - mae: 0.3205
# Epoch 149/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1557 - mae: 0.3187
# Epoch 150/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1549 - mae: 0.3176
# Epoch 151/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1539 - mae: 0.3165
# Epoch 152/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1535 - mae: 0.3158
# Epoch 153/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1527 - mae: 0.3159
# Epoch 154/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1515 - mae: 0.3133
# Epoch 155/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1513 - mae: 0.3138
# Epoch 156/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1515 - mae: 0.3134
# Epoch 157/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1513 - mae: 0.3150
# Epoch 158/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1494 - mae: 0.3107
# Epoch 159/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1481 - mae: 0.3115
# Epoch 160/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1479 - mae: 0.3097
# Epoch 161/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1462 - mae: 0.3083
# Epoch 162/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1455 - mae: 0.3079
# Epoch 163/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1450 - mae: 0.3079
# Epoch 164/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1434 - mae: 0.3054
# Epoch 165/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1426 - mae: 0.3051
# Epoch 166/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1418 - mae: 0.3042
# Epoch 167/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1421 - mae: 0.3043
# Epoch 168/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1411 - mae: 0.3043
# Epoch 169/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1404 - mae: 0.3028
# Epoch 170/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1394 - mae: 0.3010
# Epoch 171/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1395 - mae: 0.3023
# Epoch 172/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1388 - mae: 0.3004
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1370 - mae: 0.2995
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1355 - mae: 0.2979
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1351 - mae: 0.2970
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1342 - mae: 0.2957
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1350 - mae: 0.2972
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1344 - mae: 0.2978
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1344 - mae: 0.2965
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1327 - mae: 0.2943
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1312 - mae: 0.2925
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1307 - mae: 0.2921
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1306 - mae: 0.2921
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1286 - mae: 0.2898
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1282 - mae: 0.2892
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1265 - mae: 0.2876
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1265 - mae: 0.2872
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1264 - mae: 0.2871
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1245 - mae: 0.2849
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1235 - mae: 0.2841
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1229 - mae: 0.2824
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1218 - mae: 0.2815
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1214 - mae: 0.2813
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1204 - mae: 0.2802
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1203 - mae: 0.2801
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1183 - mae: 0.2783
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1190 - mae: 0.2790
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1171 - mae: 0.2768
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1163 - mae: 0.2745
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1159 - mae: 0.2754
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# /var/folders/0t/k860jmxx4d5__9h3p08nh77m0000gn/T/ipykernel_12942/819332004.py:96: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   prediction[i] = prediction[i-1] + predictionDiff[0][i-1] + slope
# /var/folders/0t/k860jmxx4d5__9h3p08nh77m0000gn/T/ipykernel_12942/819332004.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pred["SalesPred"] = prediction
# Mean Absolute Error in the test data: 1301.69
