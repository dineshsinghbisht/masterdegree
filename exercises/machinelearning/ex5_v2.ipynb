# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# # Create dataframe using input_data
# df = pd.DataFrame({'X': [1.00, 2.00, 3.00, 4.00, 5.00],
#         'Y': [1.00, 2.00, 1.30, 3.75, 2.25]})
# print(df.info())

# # Separate feature and response from dataframe
# X = df[["X"]]   # feature
# y = df["Y"]     # response
# X1 = df.iloc[:,0:1]
# y1 = df.iloc[:,-1]


# # Check the types of feature and reponse
# print(type(X))
# print(type(y))
# print(type(X1))
# print(type(y1))

# # Create and train the linear regression model
# model = LinearRegression()
# model.fit(X, y)

# # Predict the value when X = 6
# X_pred = pd.DataFrame({"X": [6]})
# y_pred = model.predict(X_pred)[0]
# print("Prediction for X = 6 is", y_pred)

# # Plot scatters and line plots 
# plt.figure(figsize=(8, 5))
# plt.scatter(X, y, label="Input Data")
# plt.plot(X, model.predict(X), label="Regression Line")
# plt.scatter(X_pred, y_pred, label="Prediction for X=6)")
# plt.xlabel("X - Feature") 
# plt.ylabel("Y - Response")
# plt.legend()
# plt.grid(True)
# plt.show()


import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array([3, 1, 5, 2, 4]).reshape(-1, 1)
y = np.array([2.0, 1.2, 3.1, 1.8, 2.5])

model = LinearRegression()
model.fit(X, y)

plt.scatter(X, y, label="Data")
plt.plot(X, model.predict(X), label="Regression line (unsorted)")
plt.legend()
plt.show()
