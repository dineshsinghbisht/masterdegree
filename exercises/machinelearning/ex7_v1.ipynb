# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Load Daily Demand data into Pandas DataFrame
df = pd.read_csv("Demand.csv", sep=';')

# # Get basic information about data
# print(df.info())

# Split the data based on the 'Day' column
train_dataset = df[df['Day'] <= 250] # Days 1 to 250 for train dataset
test_dataset = df[df['Day'] > 250] # Days 251 to 300 for test dataset

# Separate feature (X) and target (y)
X_train = train_dataset[['Day']]
y_train = train_dataset[['Demand']]

X_test = test_dataset[['Day']]
y_test = test_dataset[['Demand']]

# Fit Linear Regression model to train dataset
linreg_model = LinearRegression()
linreg_model.fit(X_train, y_train)

# Predict on test dataset
linreg_model_prediction_test = linreg_model.predict(X_test)

# Evaluate and display model accuracy with Mean Absolute Error for test dataset
print(f"Mean absolute error in test dataset using Linear Regression model: {mean_absolute_error(y_test, linreg_model_prediction_test):.2f}")

# For plotting across entire (1–300) period
X_full = df[['Day']]
y_full = df['Demand']
linreg_pred_all = linreg_model.predict(X_full)

# Plot for Linear Regression model (actual + predicted across entire period 1-300 Days)
plt.figure(figsize=(10, 6))
plt.scatter(df['Day'], y_full, label='Actual Demand')
plt.plot(df['Day'], linreg_pred_all, label='Predicted Demand', color='orange', linewidth=2)
plt.title("Actual vs Predicted Demand (Linear Regression model)")
plt.xlabel("Day")
plt.ylabel("Daily Demand")
plt.legend()
plt.show()

# Scale both feature and target for Neural Network model
scaler_x = StandardScaler()
X_train_scaled = scaler_x.fit_transform(X_train)
X_test_scaled = scaler_x.transform(X_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train)
y_test_scaled = scaler_y.transform(y_test)

# Create, compile and train a Neural Network model for Nonlinear Regression on train dataset
nn_model = tf.keras.Sequential([
    tf.keras.Input(shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(y_train_scaled.shape[1])
])

# Compile the model using Adam optimizer and Mean Squared Error loss
nn_model.compile(
    tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# Stop training early if validation loss does not improve
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=30, restore_best_weights=True
)

# Train the neural network with validation split to monitor performance
nn_model.fit(
    X_train_scaled, y_train_scaled,
    validation_split=0.2,
    shuffle=False,
    epochs=2000,
    batch_size=10,
    callbacks=[early_stop],
    #verbose=0 # Silent mode – no output printed during training
)

# Generate predictions for the test dataset
nn_model_prediction_test = nn_model.predict(X_test_scaled)

# Inverse-transform the predictions
nn_model_prediction_test = scaler_y.inverse_transform(nn_model_prediction_test)

# Inverse-transform (restore original scale) of target
y_test = scaler_y.inverse_transform(y_test_scaled)

# Evaluate and display model accuracy with Mean Absolute Error for test dataset
print(f"\nMean absolute error in test dataset using Neural Network model: {mean_absolute_error(y_test, nn_model_prediction_test):.2f}")

# For plotting across entire (1–300) period
X_full_scaled = scaler_x.transform(X_full) # Scale the input
nn_model_pred_all = nn_model.predict(X_full_scaled)
nn_model_pred_all = scaler_y.inverse_transform(nn_model_pred_all) # inverse transform the target

# Plot for Neural Network model (actual + predicted across entire period 1-300 Days)
plt.figure(figsize=(10, 6))
plt.scatter(df['Day'], y_full, label='Actual Demand')
plt.plot(df['Day'], nn_model_pred_all, label='Predicted Demand', color='red', linewidth=2)
plt.title("Actual vs Predicted Demand (Neural Network model)")
plt.xlabel("Day")
plt.ylabel("Daily Demand")
plt.legend()
plt.show()
# Out:
# Mean absolute error in test dataset using Linear Regression model: 578.07
# Epoch 1/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7578 - mae: 0.6852 - val_loss: 0.3586 - val_mae: 0.4885
# Epoch 2/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4754 - mae: 0.5478 - val_loss: 0.2605 - val_mae: 0.4059
# Epoch 3/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3697 - mae: 0.4843 - val_loss: 0.3922 - val_mae: 0.5133
# Epoch 4/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3248 - mae: 0.4549 - val_loss: 0.3464 - val_mae: 0.4784
# Epoch 5/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2939 - mae: 0.4316 - val_loss: 0.3126 - val_mae: 0.4513
# Epoch 6/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2894 - mae: 0.4287 - val_loss: 0.2898 - val_mae: 0.4318
# Epoch 7/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2747 - mae: 0.4182 - val_loss: 0.2749 - val_mae: 0.4196
# Epoch 8/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2664 - mae: 0.4129 - val_loss: 0.2602 - val_mae: 0.4065
# Epoch 9/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2618 - mae: 0.4102 - val_loss: 0.2515 - val_mae: 0.3994
# Epoch 10/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2564 - mae: 0.4065 - val_loss: 0.2465 - val_mae: 0.3969
# Epoch 11/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2558 - mae: 0.4064 - val_loss: 0.2434 - val_mae: 0.3952
# Epoch 12/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2524 - mae: 0.4042 - val_loss: 0.2420 - val_mae: 0.3943
# Epoch 13/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2524 - mae: 0.4041 - val_loss: 0.2406 - val_mae: 0.3934
# Epoch 14/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2501 - mae: 0.4037 - val_loss: 0.2401 - val_mae: 0.3931
# Epoch 15/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2503 - mae: 0.4035 - val_loss: 0.2394 - val_mae: 0.3929
# Epoch 16/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2488 - mae: 0.4035 - val_loss: 0.2392 - val_mae: 0.3929
# Epoch 17/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2490 - mae: 0.4030 - val_loss: 0.2390 - val_mae: 0.3928
# Epoch 18/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2479 - mae: 0.4032 - val_loss: 0.2388 - val_mae: 0.3928
# Epoch 19/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 0.2481 - mae: 0.4028 - val_loss: 0.2387 - val_mae: 0.3928
# Epoch 20/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 0.2473 - mae: 0.4028 - val_loss: 0.2386 - val_mae: 0.3927
# Epoch 21/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.2474 - mae: 0.4025 - val_loss: 0.2386 - val_mae: 0.3927
# Epoch 22/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 0.2467 - mae: 0.4025 - val_loss: 0.2386 - val_mae: 0.3926
# Epoch 23/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.2468 - mae: 0.4022 - val_loss: 0.2387 - val_mae: 0.3926
# Epoch 24/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.2462 - mae: 0.4022 - val_loss: 0.2388 - val_mae: 0.3925
# Epoch 25/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 0.2463 - mae: 0.4019 - val_loss: 0.2389 - val_mae: 0.3925
# Epoch 26/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2458 - mae: 0.4020 - val_loss: 0.2391 - val_mae: 0.3924
# Epoch 27/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 0.2458 - mae: 0.4017 - val_loss: 0.2393 - val_mae: 0.3925
# Epoch 28/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.2454 - mae: 0.4017 - val_loss: 0.2399 - val_mae: 0.3927
# Epoch 29/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2452 - mae: 0.4014 - val_loss: 0.2405 - val_mae: 0.3930
# Epoch 30/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 0.2449 - mae: 0.4014 - val_loss: 0.2407 - val_mae: 0.3932
# Epoch 31/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.2447 - mae: 0.4012 - val_loss: 0.2413 - val_mae: 0.3939
# Epoch 32/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.2445 - mae: 0.4011 - val_loss: 0.2418 - val_mae: 0.3945
# Epoch 33/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 0.2441 - mae: 0.4010 - val_loss: 0.2428 - val_mae: 0.3953
# Epoch 34/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.2440 - mae: 0.4008 - val_loss: 0.2441 - val_mae: 0.3967
# Epoch 35/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.2435 - mae: 0.4007 - val_loss: 0.2450 - val_mae: 0.3976
# Epoch 36/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 0.2434 - mae: 0.4005 - val_loss: 0.2460 - val_mae: 0.3986
# Epoch 37/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 0.2430 - mae: 0.4004 - val_loss: 0.2466 - val_mae: 0.3992
# Epoch 38/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2428 - mae: 0.4001 - val_loss: 0.2486 - val_mae: 0.4008
# Epoch 39/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 0.2424 - mae: 0.4000 - val_loss: 0.2503 - val_mae: 0.4024
# Epoch 40/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 0.2421 - mae: 0.3998 - val_loss: 0.2512 - val_mae: 0.4033
# Epoch 41/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.2418 - mae: 0.3995 - val_loss: 0.2532 - val_mae: 0.4051
# Epoch 42/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 0.2415 - mae: 0.3994 - val_loss: 0.2540 - val_mae: 0.4060
# Epoch 43/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2412 - mae: 0.3991 - val_loss: 0.2562 - val_mae: 0.4079
# Epoch 44/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.2408 - mae: 0.3989 - val_loss: 0.2580 - val_mae: 0.4094
# Epoch 45/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2407 - mae: 0.3987 - val_loss: 0.2597 - val_mae: 0.4108
# Epoch 46/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.2402 - mae: 0.3985 - val_loss: 0.2614 - val_mae: 0.4121
# Epoch 47/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.2402 - mae: 0.3982 - val_loss: 0.2632 - val_mae: 0.4134
# Epoch 48/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.2397 - mae: 0.3983 - val_loss: 0.2654 - val_mae: 0.4150
# Epoch 49/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2396 - mae: 0.3976 - val_loss: 0.2701 - val_mae: 0.4181
# Epoch 50/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 0.2393 - mae: 0.3980 - val_loss: 0.2674 - val_mae: 0.4163
# Epoch 51/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.2389 - mae: 0.3970 - val_loss: 0.2741 - val_mae: 0.4206
# Epoch 52/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2391 - mae: 0.3980 - val_loss: 0.2677 - val_mae: 0.4165
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
# Mean absolute error in test dataset using Neural Network model: 389.84
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
