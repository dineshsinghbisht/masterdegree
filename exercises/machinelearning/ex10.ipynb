# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVC

# Load the sensor readings dataset from a CSV file into a Pandas DataFrame 
df = pd.read_csv("sensor_readings_24.csv")

# # Get basic information about data
# print(df.info())
# print(df.columns)

# Extract all columns except the last as features (X) 
X = df.iloc[:, :-1].to_numpy()

# Scale feature values so all inputs are on the same numerical range
scaler_x = StandardScaler()
X_scaled = scaler_x.fit_transform(X)

# Encode the last column as numeric target labels (y)
enc = LabelEncoder()
y = enc.fit_transform(df.iloc[:, -1])

# Split data into train (70%) and test (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25)

# Initialize Support Vector Machine Model  
svm_model = SVC()

# Train the model on the training data
svm_model.fit(X_train,y_train)

# Generate predictions for the train and test dataset
svm_model_prediction_train = svm_model.predict(X_train)
svm_model_prediction_test = svm_model.predict(X_test)

# Evaluate and display model accuracy with Accuracy for train and test datasets
print(f"Accuracy Score in train dataset using Support Vector Machine Model: {accuracy_score(y_train, svm_model_prediction_train):.2f}")
print(f"Accuracy Score in test dataset using Support Vector Machine Model: {accuracy_score(y_test, svm_model_prediction_test):.2f}")
# Out:
# Accuracy Score in train dataset using Support Vector Machine Model: 0.91
# Accuracy Score in test dataset using Support Vector Machine Model: 0.89
